# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 0
# Read the dataset from csv file & perform data cleaning - remove all rows, which contains `?` in some columns.
# Also check for data correctness (salary & salary $K).

# %%
table = pd.read_csv("../data/adult.csv", index_col=[0])
table = table.replace("?", np.nan)
table = table.dropna(subset=["workclass", "occupation", "native-country"])
mask = (
    (table["salary"] == "<=50K") & (table["salary K$"] > 50) |
    (table["salary"] == ">50K")  & (table["salary K$"] <= 50)
)

# %% [markdown]
# # Task 1
# Print the count of men and women in the dataset.

# %%
table["sex"].value_counts()
# Out:
# sex
# Male      20380
# Female     9782
# Name: count, dtype: int64

# %% [markdown]
# # Task 2
# Find the average age of men in dataset

# %%
table[table["sex"] == "Male"]["age"].mean()
# Out:
# np.float64(39.18400392541707)

# %% [markdown]
# # Task 3
# Get the percentage of people from Poland (native-country)

# %%
(table["native-country"] == "Poland").mean() * 100
# Out:
# np.float64(0.18566408063125786)

# %% [markdown]
# # Task 4
# Get the mean and standard deviation of the age for people who earn > 50K per year. After this, get it for those who earn <= 50K.

# %%
table.groupby("salary")["age"].agg(["mean", "std"])
# Out:
#             mean        std
# salary
# <=50K   36.60806  13.464631
# >50K    43.95911  10.269633

# %% [markdown]
# # Task 5
# Check, if there are some people without higher education (education: Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters, Doctorate), but with > 50K salary

# %%
(~table["education"].isin(["Bachelors", "Prof-school", "Assoc-acdm", "Assoc-voc", "Masters", "Doctorate"])) & (table["salary"] == ">50K")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Length: 30162, dtype: bool

# %% [markdown]
# # Task 6
# Get the statistics of age for each type of education. Use `groupby` and `describe` for this.

# %%
table.groupby("education")["age"].describe()
# Out:
#                count       mean        std   min   25%   50%   75%   max
# education
# 10th           820.0  37.897561  16.225795  17.0  23.0  36.0  52.0  90.0
# 11th          1048.0  32.363550  15.089307  17.0  18.0  28.5  43.0  90.0
# 12th           377.0  32.013263  14.373710  17.0  19.0  28.0  41.0  79.0
# 1st-4th        151.0  44.622517  14.929051  19.0  33.0  44.0  56.0  81.0
# 5th-6th        288.0  41.649306  14.754622  17.0  28.0  41.0  53.0  82.0
# 7th-8th        557.0  47.631957  15.737479  17.0  34.0  49.0  60.0  90.0
# 9th            455.0  40.303297  15.335754  17.0  28.0  38.0  53.0  90.0
# Assoc-acdm    1008.0  37.286706  10.509755  19.0  29.0  36.0  44.0  90.0
# Assoc-voc     1307.0  38.246366  11.181253  19.0  30.0  37.0  45.0  84.0
# Bachelors     5044.0  38.641554  11.577566  19.0  29.0  37.0  46.0  90.0
# Doctorate      375.0  47.130667  11.471727  24.0  39.0  47.0  54.0  80.0
# HS-grad       9840.0  38.640955  13.067730  17.0  28.0  37.0  48.0  90.0
# ...

# %% [markdown]
# # Task 7
# Compare the married and non-married men salaries. Who earns more? (>50K or <=50K)
# Married men are those, whom `marital-status` starts with "Married". Others are not.

# %%
mask = table["marital-status"].str.startswith("Married")
print(table[mask & (table["sex"] == "Male")].value_counts("salary"))
print(table[~mask & (table["sex"] == "Male")].value_counts("salary"))
# Out:
# salary
# <=50K    7052
# >50K     5723
# Name: count, dtype: int64
# salary
# <=50K    6932
# >50K      673
# Name: count, dtype: int64

# %% [markdown]
# # Task 8
# Get the max hours per week some person works. How many people works the same amount of hours per week?

# %%
mask_1 = table["hours-per-week"].max()
print(mask_1)
table[table["hours-per-week"] == mask_1].shape[0]
# Out:
# 99
# 78

# %% [markdown]
# # Task 9
# Analyze the correlation between data in dataset. Understand connected fields in it and print highlight thier connection.

# %%
table.corr(numeric_only=True)
# Out:
#                      age  hours-per-week  salary K$
# age             1.000000        0.101599   0.208203
# hours-per-week  0.101599        1.000000   0.196378
# salary K$       0.208203        0.196378   1.000000
